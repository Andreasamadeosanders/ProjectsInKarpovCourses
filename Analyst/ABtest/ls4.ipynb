# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import pingouin as pg

# %%
from matplotlib import rcParams

sns.set(rc = {'figure.figsize':(16,9)})

# %%
df = pd.read_csv('experiment_lesson_4.csv')
df.head()
# Out:
#    order_id  delivery_time  district experiment_group
# 0      3159           44.0  Purlieus          control
# 1     10426           51.0  Purlieus          control
# 2      9155           46.0  Purlieus          control
# 3     10699           34.0  Purlieus          control
# 4     10061           43.0  Purlieus          control

# %%
df_control = df[df['experiment_group'] == 'control']
df_test = df[df['experiment_group'] == 'test']

# %%
sns.displot(data=df_control, kde=True, x='delivery_time', hue='district', palette=["#9b59b6", "#ff0000", "#00f0f0"], alpha=1)

# %%
sns.displot(data=df_test, kde=True, x='delivery_time', hue='district', palette=["#9b59b6", "#ff0000", "#00f0f0"], alpha=1)

# %%
df_control.shape[0]
# Out:
# 10092

# %%
df_test.shape[0]
# Out:
# 10104

# %%
abs(df_control.shape[0] - df_test.shape[0])
# Out:
# 12

# %%
df.head()
# Out:
#    order_id  delivery_time  district experiment_group
# 0      3159           44.0  Purlieus          control
# 1     10426           51.0  Purlieus          control
# 2      9155           46.0  Purlieus          control
# 3     10699           34.0  Purlieus          control
# 4     10061           43.0  Purlieus          control

# %%
pg.normality(df, dv='delivery_time', method='normaltest', group='experiment_group')
# Out:
#                 W      pval  normal
# control  0.253498  0.880955    True
# test     7.024157  0.029835   False

# %%
np.std(df_control['delivery_time'])
# Out:
# 9.989522000653128

# %%
np.std(df_test['delivery_time'])
# Out:
# 9.882819260031312

# %%
stats.ttest_ind(df_test['delivery_time'], df_control['delivery_time'])
# Out:
# Ttest_indResult(statistic=-43.03582663183714, pvalue=0.0)

# %%
test_mean = df_test['delivery_time'].mean()
control_mean = df_control['delivery_time'].mean()

# %%
x = control_mean/100

# %%
round((test_mean - control_mean)/x, 3)
# Out:
# -13.355
